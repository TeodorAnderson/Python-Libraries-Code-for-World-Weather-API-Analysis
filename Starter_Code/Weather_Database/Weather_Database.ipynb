# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]    
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description}
                          )
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | oranjestad
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | maneadero
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | umm lajj
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | esperance
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | korla
# Processing Record 13 of Set 1 | kysyl-syr
# Processing Record 14 of Set 1 | olinda
# Processing Record 15 of Set 1 | luderitz
# Processing Record 16 of Set 1 | sao jose da coroa grande
# Processing Record 17 of Set 1 | port elizabeth
# Processing Record 18 of Set 1 | nakatsu
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | tazovskiy
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | bocana de paiwas
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | te anau
# Processing Record 25 of Set 1 | tucumcari
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | katsuura
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | la palma
# Processing Record 31 of Set 1 | flinders
# Processing Record 32 of Set 1 | launceston
# Processing Record 33 of Set 1 | wenling
# Processing Record 34 of Set 1 | bethel
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | port shepstone
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | sudak
# Processing Record 39 of Set 1 | mahebourg
# Processing Record 40 of Set 1 | chapais
# Processing Record 41 of Set 1 | vila
# Processing Record 42 of Set 1 | dossor
# Processing Record 43 of Set 1 | kavaratti
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | fergus falls
# Processing Record 47 of Set 1 | provideniya
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | buin
# Processing Record 50 of Set 1 | kabare
# Processing Record 1 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | nhulunbuy
# Processing Record 5 of Set 2 | airai
# Processing Record 6 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 2 | whitehorse
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | bonavista
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 12 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 13 of Set 2 | severo-kurilsk
# Processing Record 14 of Set 2 | clyde river
# Processing Record 15 of Set 2 | coos bay
# Processing Record 16 of Set 2 | jalu
# Processing Record 17 of Set 2 | baykit
# Processing Record 18 of Set 2 | kavieng
# Processing Record 19 of Set 2 | vardo
# Processing Record 20 of Set 2 | padang
# Processing Record 21 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 2 | kruisfontein
# Processing Record 25 of Set 2 | adrar
# Processing Record 26 of Set 2 | ugoofaaru
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | flin flon
# Processing Record 30 of Set 2 | presidente medici
# Processing Record 31 of Set 2 | saskylakh
# Processing Record 32 of Set 2 | port arthur
# Processing Record 33 of Set 2 | nadvoitsy
# Processing Record 34 of Set 2 | vila franca do campo
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | mae hong son
# Processing Record 37 of Set 2 | dali
# Processing Record 38 of Set 2 | la ronge
# Processing Record 39 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 2 | olhao
# Processing Record 41 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 2 | ancud
# Processing Record 43 of Set 2 | lasa
# Processing Record 44 of Set 2 | magistralnyy
# Processing Record 45 of Set 2 | lukulu
# Processing Record 46 of Set 2 | sao joao do piaui
# Processing Record 47 of Set 2 | umm durman
# City not found. Skipping...
# Processing Record 48 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | jamestown
# Processing Record 1 of Set 3 | saint anthony
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | garca
# Processing Record 4 of Set 3 | olafsvik
# Processing Record 5 of Set 3 | port augusta
# Processing Record 6 of Set 3 | nanortalik
# Processing Record 7 of Set 3 | goderich
# Processing Record 8 of Set 3 | narsaq
# Processing Record 9 of Set 3 | lorengau
# Processing Record 10 of Set 3 | aswan
# Processing Record 11 of Set 3 | yendi
# Processing Record 12 of Set 3 | fomboni
# Processing Record 13 of Set 3 | anadyr
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | ilhabela
# Processing Record 17 of Set 3 | price
# Processing Record 18 of Set 3 | iralaya
# Processing Record 19 of Set 3 | rawson
# Processing Record 20 of Set 3 | teguldet
# Processing Record 21 of Set 3 | ambunti
# Processing Record 22 of Set 3 | iskateley
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | pisco
# Processing Record 25 of Set 3 | lagos
# Processing Record 26 of Set 3 | portland
# Processing Record 27 of Set 3 | east london
# Processing Record 28 of Set 3 | bubaque
# Processing Record 29 of Set 3 | hermanus
# Processing Record 30 of Set 3 | darab
# Processing Record 31 of Set 3 | dubbo
# Processing Record 32 of Set 3 | klaksvik
# Processing Record 33 of Set 3 | haines junction
# Processing Record 34 of Set 3 | ayan
# Processing Record 35 of Set 3 | longyearbyen
# Processing Record 36 of Set 3 | mehamn
# Processing Record 37 of Set 3 | college
# Processing Record 38 of Set 3 | jawhar
# Processing Record 39 of Set 3 | moengo
# Processing Record 40 of Set 3 | tanshui
# City not found. Skipping...
# Processing Record 41 of Set 3 | meulaboh
# Processing Record 42 of Set 3 | amahai
# Processing Record 43 of Set 3 | moose factory
# Processing Record 44 of Set 3 | mabaruma
# Processing Record 45 of Set 3 | am timan
# Processing Record 46 of Set 3 | rawah
# Processing Record 47 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 3 | nizhneangarsk
# Processing Record 49 of Set 3 | kwinana
# Processing Record 50 of Set 3 | kapit
# Processing Record 1 of Set 4 | rio brilhante
# Processing Record 2 of Set 4 | port alfred
# Processing Record 3 of Set 4 | souillac
# Processing Record 4 of Set 4 | torbay
# Processing Record 5 of Set 4 | victoria
# Processing Record 6 of Set 4 | tasiilaq
# Processing Record 7 of Set 4 | canberra
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | cherskiy
# Processing Record 10 of Set 4 | tessalit
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | kaitangata
# Processing Record 13 of Set 4 | boa vista
# Processing Record 14 of Set 4 | kosa
# Processing Record 15 of Set 4 | chokurdakh
# Processing Record 16 of Set 4 | nalut
# Processing Record 17 of Set 4 | nan
# Processing Record 18 of Set 4 | bonthe
# Processing Record 19 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 4 | tabou
# Processing Record 21 of Set 4 | saint george
# Processing Record 22 of Set 4 | shorapur
# Processing Record 23 of Set 4 | vao
# Processing Record 24 of Set 4 | vestmanna
# Processing Record 25 of Set 4 | ribeira grande
# Processing Record 26 of Set 4 | cayenne
# Processing Record 27 of Set 4 | obo
# Processing Record 28 of Set 4 | awjilah
# Processing Record 29 of Set 4 | elliot
# Processing Record 30 of Set 4 | khani
# Processing Record 31 of Set 4 | fort nelson
# Processing Record 32 of Set 4 | aksarka
# Processing Record 33 of Set 4 | santo amaro da imperatriz
# Processing Record 34 of Set 4 | alamogordo
# Processing Record 35 of Set 4 | qaqortoq
# Processing Record 36 of Set 4 | kidal
# Processing Record 37 of Set 4 | yellowknife
# Processing Record 38 of Set 4 | sur
# Processing Record 39 of Set 4 | aklavik
# Processing Record 40 of Set 4 | carahue
# Processing Record 41 of Set 4 | sedona
# Processing Record 42 of Set 4 | kasamwa
# Processing Record 43 of Set 4 | chipiona
# Processing Record 44 of Set 4 | cabo san lucas
# Processing Record 45 of Set 4 | tuktoyaktuk
# Processing Record 46 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 47 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 48 of Set 4 | dobson
# Processing Record 49 of Set 4 | turia
# Processing Record 50 of Set 4 | namatanai
# Processing Record 1 of Set 5 | high prairie
# Processing Record 2 of Set 5 | hamilton
# Processing Record 3 of Set 5 | ewa beach
# Processing Record 4 of Set 5 | natal
# Processing Record 5 of Set 5 | high level
# Processing Record 6 of Set 5 | pevek
# Processing Record 7 of Set 5 | aykhal
# Processing Record 8 of Set 5 | ca mau
# Processing Record 9 of Set 5 | lisakovsk
# Processing Record 10 of Set 5 | mbour
# Processing Record 11 of Set 5 | pavlovsk
# Processing Record 12 of Set 5 | muzhi
# Processing Record 13 of Set 5 | vondrozo
# Processing Record 14 of Set 5 | farafangana
# Processing Record 15 of Set 5 | nome
# Processing Record 16 of Set 5 | pochutla
# Processing Record 17 of Set 5 | grindavik
# Processing Record 18 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 19 of Set 5 | balsthal
# Processing Record 20 of Set 5 | maniitsoq
# Processing Record 21 of Set 5 | abeche
# Processing Record 22 of Set 5 | kahului
# Processing Record 23 of Set 5 | chiredzi
# Processing Record 24 of Set 5 | lebu
# Processing Record 25 of Set 5 | bathsheba
# Processing Record 26 of Set 5 | clinton
# Processing Record 27 of Set 5 | maunabo
# Processing Record 28 of Set 5 | kourou
# Processing Record 29 of Set 5 | castro
# Processing Record 30 of Set 5 | luebo
# Processing Record 31 of Set 5 | norman wells
# Processing Record 32 of Set 5 | vostok
# Processing Record 33 of Set 5 | vuktyl
# Processing Record 34 of Set 5 | thomasville
# Processing Record 35 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 36 of Set 5 | leningradskiy
# Processing Record 37 of Set 5 | komsomolskiy
# Processing Record 38 of Set 5 | nioro
# Processing Record 39 of Set 5 | baruun-urt
# Processing Record 40 of Set 5 | yabrud
# Processing Record 41 of Set 5 | yar-sale
# Processing Record 42 of Set 5 | porto walter
# Processing Record 43 of Set 5 | ijui
# Processing Record 44 of Set 5 | ahuimanu
# Processing Record 45 of Set 5 | sumenep
# Processing Record 46 of Set 5 | hofn
# Processing Record 47 of Set 5 | sechura
# Processing Record 48 of Set 5 | petropolis
# Processing Record 49 of Set 5 | ngunguru
# Processing Record 50 of Set 5 | alihe
# Processing Record 1 of Set 6 | jibuti
# Processing Record 2 of Set 6 | ngama
# Processing Record 3 of Set 6 | comodoro rivadavia
# Processing Record 4 of Set 6 | melo
# Processing Record 5 of Set 6 | marsh harbour
# Processing Record 6 of Set 6 | warrington
# Processing Record 7 of Set 6 | santarem
# Processing Record 8 of Set 6 | toulepleu
# City not found. Skipping...
# Processing Record 9 of Set 6 | vestmannaeyjar
# Processing Record 10 of Set 6 | ilulissat
# Processing Record 11 of Set 6 | palmer
# Processing Record 12 of Set 6 | senmonorom
# City not found. Skipping...
# Processing Record 13 of Set 6 | lere
# Processing Record 14 of Set 6 | kununurra
# Processing Record 15 of Set 6 | coquimbo
# Processing Record 16 of Set 6 | kichmengskiy gorodok
# Processing Record 17 of Set 6 | ballstad
# City not found. Skipping...
# Processing Record 18 of Set 6 | lompoc
# Processing Record 19 of Set 6 | ritchie
# Processing Record 20 of Set 6 | kashan
# Processing Record 21 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 6 | tura
# Processing Record 23 of Set 6 | winnemucca
# Processing Record 24 of Set 6 | nikolskoye
# Processing Record 25 of Set 6 | pasighat
# Processing Record 26 of Set 6 | rio gallegos
# Processing Record 27 of Set 6 | okha
# Processing Record 28 of Set 6 | xichang
# Processing Record 29 of Set 6 | ciudad real
# Processing Record 30 of Set 6 | dire dawa
# Processing Record 31 of Set 6 | alice springs
# Processing Record 32 of Set 6 | san patricio
# Processing Record 33 of Set 6 | visby
# Processing Record 34 of Set 6 | andros town
# Processing Record 35 of Set 6 | quesnel
# Processing Record 36 of Set 6 | khatanga
# Processing Record 37 of Set 6 | constitucion
# Processing Record 38 of Set 6 | carnarvon
# Processing Record 39 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 6 | obluche
# City not found. Skipping...
# Processing Record 41 of Set 6 | verkhnyaya inta
# Processing Record 42 of Set 6 | metro
# Processing Record 43 of Set 6 | bambous virieux
# Processing Record 44 of Set 6 | ranot
# Processing Record 45 of Set 6 | shemgang
# Processing Record 46 of Set 6 | fortuna
# Processing Record 47 of Set 6 | yenagoa
# Processing Record 48 of Set 6 | nyurba
# Processing Record 49 of Set 6 | san ignacio
# Processing Record 50 of Set 6 | roma
# Processing Record 1 of Set 7 | harper
# Processing Record 2 of Set 7 | mvangue
# Processing Record 3 of Set 7 | yamasaki
# Processing Record 4 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 7 | narrabri
# Processing Record 6 of Set 7 | gat
# Processing Record 7 of Set 7 | joao pinheiro
# Processing Record 8 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 7 | laurel
# Processing Record 10 of Set 7 | council bluffs
# Processing Record 11 of Set 7 | honningsvag
# Processing Record 12 of Set 7 | cockburn town
# Processing Record 13 of Set 7 | saint-francois
# Processing Record 14 of Set 7 | hvammstangi
# City not found. Skipping...
# Processing Record 15 of Set 7 | chuy
# Processing Record 16 of Set 7 | napasar
# Processing Record 17 of Set 7 | laguna
# Processing Record 18 of Set 7 | waitara
# Processing Record 19 of Set 7 | cape town
# Processing Record 20 of Set 7 | tanout
# Processing Record 21 of Set 7 | punta alta
# Processing Record 22 of Set 7 | kirensk
# Processing Record 23 of Set 7 | uruzgan
# Processing Record 24 of Set 7 | sucua
# Processing Record 25 of Set 7 | nuuk
# Processing Record 26 of Set 7 | zabolotiv
# Processing Record 27 of Set 7 | norden
# Processing Record 28 of Set 7 | hasaki
# Processing Record 29 of Set 7 | vryburg
# Processing Record 30 of Set 7 | verkhnevilyuysk
# Processing Record 31 of Set 7 | los llanos de aridane
# Processing Record 32 of Set 7 | vanimo
# Processing Record 33 of Set 7 | oistins
# Processing Record 34 of Set 7 | neyshabur
# Processing Record 35 of Set 7 | cap-aux-meules
# Processing Record 36 of Set 7 | boyolangu
# Processing Record 37 of Set 7 | port lincoln
# Processing Record 38 of Set 7 | novyye lapsary
# Processing Record 39 of Set 7 | komatipoort
# Processing Record 40 of Set 7 | balimo
# City not found. Skipping...
# Processing Record 41 of Set 7 | raudeberg
# Processing Record 42 of Set 7 | lagoa
# Processing Record 43 of Set 7 | naze
# Processing Record 44 of Set 7 | houma
# Processing Record 45 of Set 7 | lazaro cardenas
# Processing Record 46 of Set 7 | panzhihua
# Processing Record 47 of Set 7 | avera
# Processing Record 48 of Set 7 | rio grande
# Processing Record 49 of Set 7 | edwardsville
# Processing Record 50 of Set 7 | kyzyl-suu
# Processing Record 1 of Set 8 | ulaangom
# Processing Record 2 of Set 8 | yalvac
# Processing Record 3 of Set 8 | carauari
# Processing Record 4 of Set 8 | pemangkat
# Processing Record 5 of Set 8 | kutum
# Processing Record 6 of Set 8 | tarko-sale
# Processing Record 7 of Set 8 | pahrump
# Processing Record 8 of Set 8 | faanui
# Processing Record 9 of Set 8 | quatre cocos
# Processing Record 10 of Set 8 | boden
# Processing Record 11 of Set 8 | aksu
# Processing Record 12 of Set 8 | tiksi
# Processing Record 13 of Set 8 | bilibino
# Processing Record 14 of Set 8 | nakatsugawa
# Processing Record 15 of Set 8 | ixtapa
# Processing Record 16 of Set 8 | cairns
# Processing Record 17 of Set 8 | oildale
# Processing Record 18 of Set 8 | kholodnyy
# Processing Record 19 of Set 8 | husavik
# Processing Record 20 of Set 8 | parksville
# Processing Record 21 of Set 8 | estevan
# Processing Record 22 of Set 8 | codrington
# Processing Record 23 of Set 8 | iracoubo
# Processing Record 24 of Set 8 | solnechnyy
# Processing Record 25 of Set 8 | san quintin
# Processing Record 26 of Set 8 | svetlyy
# Processing Record 27 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 28 of Set 8 | santa isabel do rio negro
# Processing Record 29 of Set 8 | bereda
# Processing Record 30 of Set 8 | onega
# Processing Record 31 of Set 8 | frederico westphalen
# Processing Record 32 of Set 8 | nelson bay
# Processing Record 33 of Set 8 | cuddapah
# Processing Record 34 of Set 8 | mount isa
# Processing Record 35 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 8 | saint-louis
# Processing Record 37 of Set 8 | port hedland
# Processing Record 38 of Set 8 | trinidad
# Processing Record 39 of Set 8 | neftcala
# Processing Record 40 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 8 | brigantine
# Processing Record 42 of Set 8 | sistranda
# Processing Record 43 of Set 8 | cheyenne
# Processing Record 44 of Set 8 | olga
# Processing Record 45 of Set 8 | nyuksenitsa
# Processing Record 46 of Set 8 | bull savanna
# Processing Record 47 of Set 8 | adwa
# Processing Record 48 of Set 8 | strezhevoy
# Processing Record 49 of Set 8 | yunjinghong
# City not found. Skipping...
# Processing Record 50 of Set 8 | axim
# Processing Record 1 of Set 9 | san cristobal
# Processing Record 2 of Set 9 | monte cristi
# City not found. Skipping...
# Processing Record 3 of Set 9 | pelym
# Processing Record 4 of Set 9 | vanavara
# Processing Record 5 of Set 9 | ornskoldsvik
# Processing Record 6 of Set 9 | sosnovskoye
# Processing Record 7 of Set 9 | samarai
# Processing Record 8 of Set 9 | sale
# Processing Record 9 of Set 9 | sambava
# Processing Record 10 of Set 9 | sitka
# Processing Record 11 of Set 9 | touho
# Processing Record 12 of Set 9 | svetlogorsk
# Processing Record 13 of Set 9 | riedlingen
# Processing Record 14 of Set 9 | belmonte
# Processing Record 15 of Set 9 | brae
# Processing Record 16 of Set 9 | ahipara
# Processing Record 17 of Set 9 | sembakung
# Processing Record 18 of Set 9 | belton
# Processing Record 19 of Set 9 | maumere
# Processing Record 20 of Set 9 | asau
# Processing Record 21 of Set 9 | malakal
# Processing Record 22 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 23 of Set 9 | agadez
# Processing Record 24 of Set 9 | havelock
# Processing Record 25 of Set 9 | ulagan
# Processing Record 26 of Set 9 | praia da vitoria
# Processing Record 27 of Set 9 | isangel
# Processing Record 28 of Set 9 | berdigestyakh
# Processing Record 29 of Set 9 | barra do garcas
# Processing Record 30 of Set 9 | impfondo
# Processing Record 31 of Set 9 | cumana
# Processing Record 32 of Set 9 | barra patuca
# Processing Record 33 of Set 9 | puerto quijarro
# Processing Record 34 of Set 9 | eureka
# Processing Record 35 of Set 9 | hami
# Processing Record 36 of Set 9 | saldanha
# Processing Record 37 of Set 9 | margate
# Processing Record 38 of Set 9 | salalah
# Processing Record 39 of Set 9 | camapua
# Processing Record 40 of Set 9 | sao filipe
# Processing Record 41 of Set 9 | winneba
# Processing Record 42 of Set 9 | kulhudhuffushi
# Processing Record 43 of Set 9 | vallenar
# Processing Record 44 of Set 9 | chicama
# Processing Record 45 of Set 9 | atar
# Processing Record 46 of Set 9 | fort abbas
# Processing Record 47 of Set 9 | ierapetra
# Processing Record 48 of Set 9 | uyuni
# Processing Record 49 of Set 9 | dabat
# Processing Record 50 of Set 9 | leh
# Processing Record 1 of Set 10 | kautokeino
# Processing Record 2 of Set 10 | zarate
# Processing Record 3 of Set 10 | makakilo city
# Processing Record 4 of Set 10 | moundsville
# Processing Record 5 of Set 10 | guaruja
# Processing Record 6 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 10 | oussouye
# Processing Record 8 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 10 of Set 10 | river falls
# Processing Record 11 of Set 10 | lavrentiya
# Processing Record 12 of Set 10 | papara
# Processing Record 13 of Set 10 | hope
# Processing Record 14 of Set 10 | japura
# Processing Record 15 of Set 10 | paamiut
# Processing Record 16 of Set 10 | marienburg
# Processing Record 17 of Set 10 | santona
# Processing Record 18 of Set 10 | aberystwyth
# Processing Record 19 of Set 10 | poum
# Processing Record 20 of Set 10 | mayo
# Processing Record 21 of Set 10 | pringsewu
# Processing Record 22 of Set 10 | kupang
# Processing Record 23 of Set 10 | urman
# Processing Record 24 of Set 10 | iqaluit
# Processing Record 25 of Set 10 | ozernovskiy
# Processing Record 26 of Set 10 | victoria point
# Processing Record 27 of Set 10 | healdsburg
# Processing Record 28 of Set 10 | hambantota
# Processing Record 29 of Set 10 | hervey bay
# Processing Record 30 of Set 10 | calabozo
# Processing Record 31 of Set 10 | teabo
# Processing Record 32 of Set 10 | eyl
# Processing Record 33 of Set 10 | russell
# Processing Record 34 of Set 10 | thanh hoa
# Processing Record 35 of Set 10 | sembe
# Processing Record 36 of Set 10 | sumbe
# Processing Record 37 of Set 10 | kasongo-lunda
# Processing Record 38 of Set 10 | aktash
# Processing Record 39 of Set 10 | walvis bay
# Processing Record 40 of Set 10 | kurchum
# Processing Record 41 of Set 10 | egvekinot
# Processing Record 42 of Set 10 | dunedin
# Processing Record 43 of Set 10 | ostrovnoy
# Processing Record 44 of Set 10 | severo-yeniseyskiy
# Processing Record 45 of Set 10 | seydi
# Processing Record 46 of Set 10 | pergamino
# Processing Record 47 of Set 10 | beloha
# Processing Record 48 of Set 10 | rumoi
# Processing Record 49 of Set 10 | geraldton
# Processing Record 50 of Set 10 | meadow lake
# Processing Record 1 of Set 11 | gravelbourg
# Processing Record 2 of Set 11 | pangkalanbuun
# Processing Record 3 of Set 11 | taltal
# Processing Record 4 of Set 11 | kushmurun
# Processing Record 5 of Set 11 | nicoya
# Processing Record 6 of Set 11 | belaya gora
# Processing Record 7 of Set 11 | gigmoto
# Processing Record 8 of Set 11 | muros
# Processing Record 9 of Set 11 | zapote
# Processing Record 10 of Set 11 | sinnamary
# Processing Record 11 of Set 11 | fuling
# Processing Record 12 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 14 of Set 11 | vila velha
# Processing Record 15 of Set 11 | mahibadhoo
# Processing Record 16 of Set 11 | tevaitoa
# Processing Record 17 of Set 11 | sibolga
# Processing Record 18 of Set 11 | hanzhong
# Processing Record 19 of Set 11 | sorland
# Processing Record 20 of Set 11 | stuttgart
# Processing Record 21 of Set 11 | yuli
# Processing Record 22 of Set 11 | baiyin
# Processing Record 23 of Set 11 | umm kaddadah
# Processing Record 24 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 11 | noyabrsk
# Processing Record 26 of Set 11 | breves
# Processing Record 27 of Set 11 | salo
# Processing Record 28 of Set 11 | bunia
# Processing Record 29 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 30 of Set 11 | alice town
# Processing Record 31 of Set 11 | lerwick
# Processing Record 32 of Set 11 | north battleford
# Processing Record 33 of Set 11 | coruripe
# Processing Record 34 of Set 11 | sao felix do xingu
# Processing Record 35 of Set 11 | kamakwie
# Processing Record 36 of Set 11 | chumikan
# Processing Record 37 of Set 11 | fonte boa
# Processing Record 38 of Set 11 | letlhakane
# Processing Record 39 of Set 11 | sobolevo
# Processing Record 40 of Set 11 | waipawa
# Processing Record 41 of Set 11 | zima
# Processing Record 42 of Set 11 | alenquer
# Processing Record 43 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 11 | firminopolis
# Processing Record 46 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 47 of Set 11 | lodja
# Processing Record 48 of Set 11 | palu
# Processing Record 49 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 50 of Set 11 | astoria
# Processing Record 1 of Set 12 | matai
# Processing Record 2 of Set 12 | khash
# Processing Record 3 of Set 12 | tateyama
# Processing Record 4 of Set 12 | esso
# Processing Record 5 of Set 12 | caravelas
# Processing Record 6 of Set 12 | nchelenge
# Processing Record 7 of Set 12 | guerande
# Processing Record 8 of Set 12 | marsa matruh
# Processing Record 9 of Set 12 | rosarito
# Processing Record 10 of Set 12 | north bend
# Processing Record 11 of Set 12 | heihe
# Processing Record 12 of Set 12 | saint-augustin
# Processing Record 13 of Set 12 | amsterdam
# Processing Record 14 of Set 12 | turan
# Processing Record 15 of Set 12 | rabo de peixe
# Processing Record 16 of Set 12 | sao joao da barra
# Processing Record 17 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 12 | tovuz
# Processing Record 19 of Set 12 | tazmalt
# Processing Record 20 of Set 12 | dhidhdhoo
# Processing Record 21 of Set 12 | puerto colombia
# Processing Record 22 of Set 12 | arroyo
# Processing Record 23 of Set 12 | alkhan-yurt
# Processing Record 24 of Set 12 | san ramon
# Processing Record 25 of Set 12 | guerrero negro
# Processing Record 26 of Set 12 | labuhan
# Processing Record 27 of Set 12 | el sauz
# Processing Record 28 of Set 12 | kamiiso
# Processing Record 29 of Set 12 | siljan
# Processing Record 30 of Set 12 | springdale
# Processing Record 31 of Set 12 | zhezkazgan
# Processing Record 32 of Set 12 | kjollefjord
# Processing Record 33 of Set 12 | kita
# Processing Record 34 of Set 12 | abu kamal
# Processing Record 35 of Set 12 | zonguldak
# Processing Record 36 of Set 12 | disna
# Processing Record 37 of Set 12 | bilma
# Processing Record 38 of Set 12 | senador jose porfirio
# Processing Record 39 of Set 12 | troitskoye
# Processing Record 40 of Set 12 | eydhafushi
# Processing Record 41 of Set 12 | jayanca
# Processing Record 42 of Set 12 | talnakh
# Processing Record 43 of Set 12 | riyadh
# Processing Record 44 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 12 | rabaul
# Processing Record 46 of Set 12 | matara
# Processing Record 47 of Set 12 | sayyan
# Processing Record 48 of Set 12 | bara
# Processing Record 49 of Set 12 | bardiyah
# Processing Record 50 of Set 12 | kuva
# City not found. Skipping...
# Processing Record 1 of Set 13 | sabang
# Processing Record 2 of Set 13 | maridi
# Processing Record 3 of Set 13 | nuevo progreso
# Processing Record 4 of Set 13 | belfast
# Processing Record 5 of Set 13 | ekibastuz
# Processing Record 6 of Set 13 | manokwari
# Processing Record 7 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 13 | porto novo
# Processing Record 9 of Set 13 | columbine
# Processing Record 10 of Set 13 | urumqi
# Processing Record 11 of Set 13 | acapulco
# Processing Record 12 of Set 13 | changji
# Processing Record 13 of Set 13 | isla mujeres
# Processing Record 14 of Set 13 | kinanah
# City not found. Skipping...
# Processing Record 15 of Set 13 | alofi
# Processing Record 16 of Set 13 | pudozh
# Processing Record 17 of Set 13 | yairipok
# Processing Record 18 of Set 13 | andenes
# Processing Record 19 of Set 13 | la peca
# Processing Record 20 of Set 13 | kyabe
# Processing Record 21 of Set 13 | uspenka
# Processing Record 22 of Set 13 | derzhavinsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 571

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton -33.6500  115.3333     79.00        49          18
# 1       Oranjestad  12.5240  -70.0270     78.91        82           0
# 2         Thompson  55.7435  -97.8558    -17.55        97          91
# 3             Hilo  19.7297 -155.0900     78.28        95          75
# 4        Maneadero  31.7167 -116.5667     64.71        34           0
# 5          Ushuaia -54.8000  -68.3000     47.86        61          40
# 6         Umm Lajj  25.0213   37.2685     66.72        64          41
# 7  Arraial Do Cabo -22.9661  -42.0278     71.26        86          64
# 8        Esperance -33.8667  121.9000     72.00        67          35
# 9          Rikitea -23.1203 -134.9692     77.20        79          17
#
#    Wind Speed Country Current Description
# 0       10.67      AU          few clouds
# 1        1.01      AW           clear sky
# 2        3.24      CA     overcast clouds
# 3        0.00      US       broken clouds
# 4        7.72      MX           clear sky
# 5       28.77      AR    scattered clouds
# 6        5.50      SA    scattered clouds
# 7       20.45      BR       broken clouds
# 8       13.33      AU    scattered clouds
# 9        9.22      PF          few clouds

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton -33.6500  115.3333     79.00        49          18
# 1       Oranjestad  12.5240  -70.0270     78.91        82           0
# 2         Thompson  55.7435  -97.8558    -17.55        97          91
# 3             Hilo  19.7297 -155.0900     78.28        95          75
# 4        Maneadero  31.7167 -116.5667     64.71        34           0
# 5          Ushuaia -54.8000  -68.3000     47.86        61          40
# 6         Umm Lajj  25.0213   37.2685     66.72        64          41
# 7  Arraial Do Cabo -22.9661  -42.0278     71.26        86          64
# 8        Esperance -33.8667  121.9000     72.00        67          35
# 9          Rikitea -23.1203 -134.9692     77.20        79          17
#
#    Wind Speed Country Current Description
# 0       10.67      AU          few clouds
# 1        1.01      AW           clear sky
# 2        3.24      CA     overcast clouds
# 3        0.00      US       broken clouds
# 4        7.72      MX           clear sky
# 5       28.77      AR    scattered clouds
# 6        5.50      SA    scattered clouds
# 7       20.45      BR       broken clouds
# 8       13.33      AU    scattered clouds
# 9        9.22      PF          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Busselton      AU -33.6500  115.3333     79.00        49          18
# 1       Oranjestad      AW  12.5240  -70.0270     78.91        82           0
# 2         Thompson      CA  55.7435  -97.8558    -17.55        97          91
# 3             Hilo      US  19.7297 -155.0900     78.28        95          75
# 4        Maneadero      MX  31.7167 -116.5667     64.71        34           0
# 5          Ushuaia      AR -54.8000  -68.3000     47.86        61          40
# 6         Umm Lajj      SA  25.0213   37.2685     66.72        64          41
# 7  Arraial Do Cabo      BR -22.9661  -42.0278     71.26        86          64
# 8        Esperance      AU -33.8667  121.9000     72.00        67          35
# 9          Rikitea      PF -23.1203 -134.9692     77.20        79          17
#
#    Wind Speed Current Description
# 0       10.67          few clouds
# 1        1.01           clear sky
# 2        3.24     overcast clouds
# 3        0.00       broken clouds
# 4        7.72           clear sky
# 5       28.77    scattered clouds
# 6        5.50    scattered clouds
# 7       20.45       broken clouds
# 8       13.33    scattered clouds
# 9        9.22          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "./WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
